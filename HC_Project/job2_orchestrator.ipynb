# %%
# %python
import requests

# Configuration
DATABRICKS_INSTANCE = "dbc-e85a0cf6-ef47.cloud.databricks.com"  # e.g., adb-1234567890123456.7.azuredatabricks.net
JOB_2_ID = 29554446109878  # e.g., 12345


# API endpoint
url = f"https://{DATABRICKS_INSTANCE}/api/2.1/jobs/run-now"

# Request payload
payload = {
    "job_id": JOB_2_ID
}

# Headers
headers = {
    "Authorization": f"Bearer {TOKEN}"
}

# Trigger Job 2
response = requests.post(url, json=payload, headers=headers)

# Check response
if response.status_code == 200:
    print("Job 2 triggered successfully!")
else:
    print(f"Failed to trigger Job 2: {response.text}")
